# %%
# python -m streamlit run prevert.py

from collections import defaultdict
import pandas as pd
import numpy as np
import re
from unidecode import unidecode
# from utils import tokenize

from google.oauth2 import service_account
import streamlit as st
credentials = service_account.Credentials.from_service_account_info(st.secrets["gcp_service_account"])

def tokenize(text):
    return re.sub(' +', ' ', re.sub("\W+", ' ', unidecode(text.lower()))).strip(' \n')

# %%
def bq_load_v1():
    # archive from data_v1 (i.e. all scrapping)
    data_v1 = pd.read_parquet('data_v2/raw_data_v1_17_nov_.parquet') 
    data_v1['note'] = data_v1['vo']
    data_v1['all_search'] = (data_v1['text_tok'].astype(str)) + (data_v1['author'].astype(str).apply(tokenize)) + (data_v1['book'].astype(str).apply(tokenize)) + (data_v1['title'].astype(str).apply(tokenize)) + data_v1['quote_react'].astype(str)
    data_v1.set_index('text_tok', inplace = True, drop = True)
    data_v1.drop(['year', 'source', 'confiance', 'page', 'url', 'nb_char', 'nb_lines', 'sonnet', 'vo'], axis = 1, inplace = True)
    data_v1['is_delete'] = False
    return data_v1

def bq_update_events_pandas(events):
    # format events into pandas
    events['text'] = events['quote'].apply(lambda x: x.get('text', ''))
    events['text_tok'] = events['quote'].apply(lambda x: x.get('text', '')) # no tokenize (events text_tok are consider as is (will be tokenize in all_search))
    events['text_tok'] = events['info'].apply(lambda x: x.get('text_tok', '')) # no tokenize (events text_tok are consider as is (will be tokenize in all_search))
    events['author'] = events['quote'].apply(lambda x: x.get('author', ''))
    events['book'] = events['quote'].apply(lambda x: x.get('book', ''))
    events['title'] = events['quote'].apply(lambda x: x.get('title', ''))
    events['quote_react'] = events['extra'].apply(lambda x: x.get('quote_react', ''))
    events['note'] = events['extra'].apply(lambda x: x.get('note', ''))
    events['haiku'] = events['text'].apply(lambda x: len(x.split('\n')) == 3)
    events['nb_like'] = events['quote_react'].apply(lambda x: (len(x) * 50) if x is not None else 0)
    events['all_search'] = (events['text_tok'].astype(str).apply(tokenize)) + ' ' + (events['author'].astype(str).apply(tokenize)) +' ' + (events['book'].astype(str).apply(tokenize)) + ' ' +(events['title'].astype(str).apply(tokenize)) +' ' + events['quote_react'].astype(str)
    events = events[['text', 'author', 'book', 'title', 'nb_like', 'text_tok', 'haiku', 'quote_react', 'note', 'all_search', 'is_delete']]
    events.set_index('text_tok', inplace = True, drop = True)
    return events

# %%
credentials = service_account.Credentials.from_service_account_info(st.secrets["gcp_service_account"])

# load data_v1
data_v1 = bq_load_v1()
# st.write('data_v1 loaded')

# load events
with open('bq_view_updated.sql', 'r') as f:
    query_view = f.read()
events_updated = pd.read_gbq(query_view, credentials=credentials)
# st.write(f'{len(events_updated)} events loaded')

# format events into pandas
df_updated = bq_update_events_pandas(events_updated)

# delete & duplicate
data_ram = pd.concat([df_updated, data_v1], axis = 0)
data_ram['is_delete'] = data_ram['is_delete'].replace(np.nan, False)
data_ram = data_ram[~data_ram.index.duplicated(keep='first')]
data_ram = data_ram[~data_ram['is_delete']]
data_ram.drop(['is_delete', 'all_search'], axis = 1, inplace = True)

# astype
data_ram['author'] = data_ram['author'].astype(str)
data_ram['book'] = data_ram['book'].astype(str).replace('None', None)
data_ram['title'] = data_ram['title'].astype(str).replace('nan', None)
data_ram['quote_react'] = data_ram['quote_react'].astype(str).replace('None', None)
data_ram['note'] = data_ram['note'].astype(str).replace('nan', None)
data_ram['text'] = data_ram['text'].astype(str)
data_ram['haiku'] = data_ram['haiku'].astype(bool)
data_ram['nb_like'] = data_ram['nb_like'].astype(int)
data_ram.sort_values('nb_like', ascending = False, inplace = True)

# %%
aa = pd.concat([df_updated, data_v1], axis = 0)
aa[aa['author'] == 'Prevert']
# Out:
#                                                                                                  text  \
# text_tok
# notre pere qui etes aux cieux restez y et nous ...  Notre Père qui êtes aux cieux  \nRestez-y  \nE...
# j ai mis mon kepi dans la cage et je suis sorti...  J'ai mis mon képi dans la cage  \net je suis s...
# rappelle toi barbara il pleuvait sans cesse sur...  Rappelle-toi Barbara  \nIl pleuvait sans cesse...
# qui sourit n est pas toujours heureux il y a de...  Embauché malgré moi dans l’usine à idées  /n/j...
# deux et deux quatre quatre et quatre huit huit ...  Deux et deux quatre  \nQuatre et quatre huit  ...
# il a mis le cafe dans la tasse il a mis le lait...  Il a mis le café  \nDans la tasse  \nIl a mis ...
# peindre d abord une cage avec une porte ouverte...  Peindre d'abord une cage  \navec une porte ouv...
# notre pere qui etes aux cieux restez y et nous ...  Notre Père qui êtes aux cieux  \nRestez-y  \nE...
# il y en a qui s appellent aime bienvenu ou desi...  Il y en a qui s’appellent  \nAimé Bienvenu ou ...
# j ai mis mon kepi dans la cage et je suis sorti...  J'ai mis mon képi dans la cage  \net je suis s...
# vous je ne vous regarde pas ma vie non plus ne ...  Vous  \nJe ne vous regarde pas  \nma vie non p...
# trois allumettes une a une allumees dans la nui...  Trois allumettes, une à une allumées dans la n...
# rappelle toi barbara il pleuvait sans cesse sur...  Rappelle-toi Barbara  \nIl pleuvait sans cesse...
#
#                                                      author  book  \
# text_tok
# notre pere qui etes aux cieux restez y et nous ...  Prevert  None
# j ai mis mon kepi dans la cage et je suis sorti...  Prevert  None
# rappelle toi barbara il pleuvait sans cesse sur...  Prevert  None
# qui sourit n est pas toujours heureux il y a de...  Prevert  None
# deux et deux quatre quatre et quatre huit huit ...  Prevert  None
# il a mis le cafe dans la tasse il a mis le lait...  Prevert  None
# peindre d abord une cage avec une porte ouverte...  Prevert  None
# notre pere qui etes aux cieux restez y et nous ...  Prevert  None
# il y en a qui s appellent aime bienvenu ou desi...  Prevert  None
# j ai mis mon kepi dans la cage et je suis sorti...  Prevert  None
# vous je ne vous regarde pas ma vie non plus ne ...  Prevert  None
# trois allumettes une a une allumees dans la nui...  Prevert  None
# rappelle toi barbara il pleuvait sans cesse sur...  Prevert  None
#
#                                                                                  title  \
# text_tok
# notre pere qui etes aux cieux restez y et nous ...                        Pater noster
# j ai mis mon kepi dans la cage et je suis sorti...                      Quartier libre
# rappelle toi barbara il pleuvait sans cesse sur...                            Barabara
# qui sourit n est pas toujours heureux il y a de...                                None
# deux et deux quatre quatre et quatre huit huit ...                     Page d'écriture
# il a mis le cafe dans la tasse il a mis le lait...                   Déjeuner du matin
# peindre d abord une cage avec une porte ouverte...  Pour faire le portrait d'un oiseau
# notre pere qui etes aux cieux restez y et nous ...                        Pater noster
# il y en a qui s appellent aime bienvenu ou desi...          Il y en a qui s’appellent…
# j ai mis mon kepi dans la cage et je suis sorti...                      Quartier libre
# vous je ne vous regarde pas ma vie non plus ne ...                    Droits de regard
# trois allumettes une a une allumees dans la nui...                      Paris at night
# rappelle toi barbara il pleuvait sans cesse sur...                            Barabara
#
#                                                     nb_like  haiku  \
# text_tok
# notre pere qui etes aux cieux restez y et nous ...      0.0  False
# j ai mis mon kepi dans la cage et je suis sorti...      0.0  False
# rappelle toi barbara il pleuvait sans cesse sur...      0.0  False
# qui sourit n est pas toujours heureux il y a de...      0.0  False
# deux et deux quatre quatre et quatre huit huit ...    150.0  False
# il a mis le cafe dans la tasse il a mis le lait...    150.0  False
# peindre d abord une cage avec une porte ouverte...     50.0  False
# notre pere qui etes aux cieux restez y et nous ...      0.0  False
# il y en a qui s appellent aime bienvenu ou desi...      0.0  False
# j ai mis mon kepi dans la cage et je suis sorti...      0.0  False
# vous je ne vous regarde pas ma vie non plus ne ...      0.0  False
# trois allumettes une a une allumees dans la nui...      0.0  False
# rappelle toi barbara il pleuvait sans cesse sur...      0.0  False
#
#                                                    quote_react  note  \
# text_tok
# notre pere qui etes aux cieux restez y et nous ...        None  None
# j ai mis mon kepi dans la cage et je suis sorti...        None  None
# rappelle toi barbara il pleuvait sans cesse sur...        None  None
# qui sourit n est pas toujours heureux il y a de...        None  None
# deux et deux quatre quatre et quatre huit huit ...         🦎🌈🦋   nan
# il a mis le cafe dans la tasse il a mis le lait...         🎶🔥🌈   nan
# peindre d abord une cage avec une porte ouverte...           🦋   nan
# notre pere qui etes aux cieux restez y et nous ...        None   nan
# il y en a qui s appellent aime bienvenu ou desi...        None   nan
# j ai mis mon kepi dans la cage et je suis sorti...        None   nan
# vous je ne vous regarde pas ma vie non plus ne ...        None   nan
# trois allumettes une a une allumees dans la nui...        None   nan
# rappelle toi barbara il pleuvait sans cesse sur...        None   nan
#
#                                                                                            all_search  \
# text_tok
# notre pere qui etes aux cieux restez y et nous ...  notre pere qui etes aux cieux restez y et nous...
# j ai mis mon kepi dans la cage et je suis sorti...  j ai mis mon kepi dans la cage et je suis sort...
# rappelle toi barbara il pleuvait sans cesse sur...  rappelle toi barbara il pleuvait sans cesse su...
# qui sourit n est pas toujours heureux il y a de...  qui sourit n est pas toujours heureux il y a d...
# deux et deux quatre quatre et quatre huit huit ...  deux et deux quatre quatre et quatre huit huit...
# il a mis le cafe dans la tasse il a mis le lait...  il a mis le cafe dans la tasse il a mis le lai...
# peindre d abord une cage avec une porte ouverte...  peindre d abord une cage avec une porte ouvert...
# notre pere qui etes aux cieux restez y et nous ...  notre pere qui etes aux cieux restez y et nous...
# il y en a qui s appellent aime bienvenu ou desi...  il y en a qui s appellent aime bienvenu ou des...
# j ai mis mon kepi dans la cage et je suis sorti...  j ai mis mon kepi dans la cage et je suis sort...
# vous je ne vous regarde pas ma vie non plus ne ...  vous je ne vous regarde pas ma vie non plus ne...
# trois allumettes une a une allumees dans la nui...  trois allumettes une a une allumees dans la nu...
# rappelle toi barbara il pleuvait sans cesse sur...  rappelle toi barbara il pleuvait sans cesse su...
#
#                                                    is_delete
# text_tok
# notre pere qui etes aux cieux restez y et nous ...      True
# j ai mis mon kepi dans la cage et je suis sorti...      <NA>
# rappelle toi barbara il pleuvait sans cesse sur...      True
# qui sourit n est pas toujours heureux il y a de...      <NA>
# deux et deux quatre quatre et quatre huit huit ...     False
# il a mis le cafe dans la tasse il a mis le lait...     False
# peindre d abord une cage avec une porte ouverte...     False
# notre pere qui etes aux cieux restez y et nous ...     False
# il y en a qui s appellent aime bienvenu ou desi...     False
# j ai mis mon kepi dans la cage et je suis sorti...     False
# vous je ne vous regarde pas ma vie non plus ne ...     False
# trois allumettes une a une allumees dans la nui...     False
# rappelle toi barbara il pleuvait sans cesse sur...     False

# %%
data_ram[data_ram['author'] == 'Jane Austen']
# Out:
#                                                                                                  text  \
# text_tok
# depuis le commencement je pourrais dire des le ...  Depuis le commencement, je pourrais dire dès l...
# je lui aurais volontiers pardonne son orgueil s...  Je lui aurais volontiers pardonné son orgueil ...
#
#                                                          author  \
# text_tok
# depuis le commencement je pourrais dire des le ...  Jane Austen
# je lui aurais volontiers pardonne son orgueil s...  Jane Austen
#
#                                                                    book title  \
# text_tok
# depuis le commencement je pourrais dire des le ...  Orgueil et préjugés  None
# je lui aurais volontiers pardonne son orgueil s...  Orgueil et préjugés  None
#
#                                                     nb_like  haiku  \
# text_tok
# depuis le commencement je pourrais dire des le ...      395  False
# je lui aurais volontiers pardonne son orgueil s...      313  False
#
#                                                    quote_react  note
# text_tok
# depuis le commencement je pourrais dire des le ...        None  None
# je lui aurais volontiers pardonne son orgueil s...        None  None

# %%
data_ram.loc['qui sourit n est pas toujours heureux il y a des larmes dans le coeur qui n atteignent pas les yeux orgueil et prejuges']['text']
# Out:
# 'Embauché malgré moi dans l’usine à idées  /n/j’ai refusé de pointer  /n/Mobilisé de même dans l’armée des idées  /n/j’ai déserté  /n/Je n’ai jamais compris grand chose  /n/Il n’y a jamais grand chose  /n/ni petite chose  /n/il y a autre chose  /n/Autre chose  /n/c’est ce que j’aime qui me plaît  /n/et que je fais.'

# %%
data_ram[data_ram['author'] == 'Prevert']
# Out:
#                                                                                                  text  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...  Il a mis le café  \nDans la tasse  \nIl a mis ...
# deux et deux quatre quatre et quatre huit huit ...  Deux et deux quatre  \nQuatre et quatre huit  ...
# peindre d abord une cage avec une porte ouverte...  Peindre d'abord une cage  \navec une porte ouv...
# rappelle toi barbara il pleuvait sans cesse sur...  Rappelle-toi Barbara  \nIl pleuvait sans cesse...
# notre pere qui etes aux cieux restez y et nous ...  Notre Père qui êtes aux cieux  \nRestez-y  \nE...
# il y en a qui s appellent aime bienvenu ou desi...  Il y en a qui s’appellent  \nAimé Bienvenu ou ...
# j ai mis mon kepi dans la cage et je suis sorti...  J'ai mis mon képi dans la cage  \net je suis s...
# vous je ne vous regarde pas ma vie non plus ne ...  Vous  \nJe ne vous regarde pas  \nma vie non p...
# trois allumettes une a une allumees dans la nui...  Trois allumettes, une à une allumées dans la n...
#
#                                                      author  book  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...  Prevert  None
# deux et deux quatre quatre et quatre huit huit ...  Prevert  None
# peindre d abord une cage avec une porte ouverte...  Prevert  None
# rappelle toi barbara il pleuvait sans cesse sur...  Prevert  None
# notre pere qui etes aux cieux restez y et nous ...  Prevert  None
# il y en a qui s appellent aime bienvenu ou desi...  Prevert  None
# j ai mis mon kepi dans la cage et je suis sorti...  Prevert  None
# vous je ne vous regarde pas ma vie non plus ne ...  Prevert  None
# trois allumettes une a une allumees dans la nui...  Prevert  None
#
#                                                                                  title  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...                   Déjeuner du matin
# deux et deux quatre quatre et quatre huit huit ...                     Page d'écriture
# peindre d abord une cage avec une porte ouverte...  Pour faire le portrait d'un oiseau
# rappelle toi barbara il pleuvait sans cesse sur...                            Barabara
# notre pere qui etes aux cieux restez y et nous ...                        Pater noster
# il y en a qui s appellent aime bienvenu ou desi...          Il y en a qui s’appellent…
# j ai mis mon kepi dans la cage et je suis sorti...                      Quartier libre
# vous je ne vous regarde pas ma vie non plus ne ...                    Droits de regard
# trois allumettes une a une allumees dans la nui...                      Paris at night
#
#                                                     nb_like  haiku  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...      150  False
# deux et deux quatre quatre et quatre huit huit ...      150  False
# peindre d abord une cage avec une porte ouverte...       50  False
# rappelle toi barbara il pleuvait sans cesse sur...        0  False
# notre pere qui etes aux cieux restez y et nous ...        0  False
# il y en a qui s appellent aime bienvenu ou desi...        0  False
# j ai mis mon kepi dans la cage et je suis sorti...        0  False
# vous je ne vous regarde pas ma vie non plus ne ...        0  False
# trois allumettes une a une allumees dans la nui...        0  False
#
#                                                    quote_react  note
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...         🎶🔥🌈  None
# deux et deux quatre quatre et quatre huit huit ...         🦎🌈🦋  None
# peindre d abord une cage avec une porte ouverte...           🦋  None
# rappelle toi barbara il pleuvait sans cesse sur...        None  None
# notre pere qui etes aux cieux restez y et nous ...        None  None
# il y en a qui s appellent aime bienvenu ou desi...        None  None
# j ai mis mon kepi dans la cage et je suis sorti...        None  None
# vous je ne vous regarde pas ma vie non plus ne ...        None  None
# trois allumettes une a une allumees dans la nui...        None  None

# %%
data_ram = pd.read_parquet('data_v2/data_ram.parquet')
data_ram[data_ram['author'] == 'Jane Austen']
data_ram[data_ram['author'] == 'Prevert']
# Out:
#                                                                                                  text  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...  Il a mis le café  \nDans la tasse  \nIl a mis ...
# deux et deux quatre quatre et quatre huit huit ...  Deux et deux quatre  \nQuatre et quatre huit  ...
# peindre d abord une cage avec une porte ouverte...  Peindre d'abord une cage  \navec une porte ouv...
# rappelle toi barbara il pleuvait sans cesse sur...  Rappelle-toi Barbara  \nIl pleuvait sans cesse...
# J'ai mis mon képi dans la cage  \net je suis so...  J'ai mis mon képi dans la cage  \net je suis s...
# Embauché malgré moi dans l’usine à idées  /n/j’...  Embauché malgré moi dans l’usine à idées  /n/j...
# notre pere qui etes aux cieux restez y et nous ...  Notre Père qui êtes aux cieux  \nRestez-y  \nE...
# il y en a qui s appellent aime bienvenu ou desi...  Il y en a qui s’appellent  \nAimé Bienvenu ou ...
# j ai mis mon kepi dans la cage et je suis sorti...  J'ai mis mon képi dans la cage  \net je suis s...
# vous je ne vous regarde pas ma vie non plus ne ...  Vous  \nJe ne vous regarde pas  \nma vie non p...
# trois allumettes une a une allumees dans la nui...  Trois allumettes, une à une allumées dans la n...
#
#                                                      author  book  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...  Prevert  None
# deux et deux quatre quatre et quatre huit huit ...  Prevert  None
# peindre d abord une cage avec une porte ouverte...  Prevert  None
# rappelle toi barbara il pleuvait sans cesse sur...  Prevert  None
# J'ai mis mon képi dans la cage  \net je suis so...  Prevert  None
# Embauché malgré moi dans l’usine à idées  /n/j’...  Prevert  None
# notre pere qui etes aux cieux restez y et nous ...  Prevert  None
# il y en a qui s appellent aime bienvenu ou desi...  Prevert  None
# j ai mis mon kepi dans la cage et je suis sorti...  Prevert  None
# vous je ne vous regarde pas ma vie non plus ne ...  Prevert  None
# trois allumettes une a une allumees dans la nui...  Prevert  None
#
#                                                                                  title  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...                   Déjeuner du matin
# deux et deux quatre quatre et quatre huit huit ...                     Page d'écriture
# peindre d abord une cage avec une porte ouverte...  Pour faire le portrait d'un oiseau
# rappelle toi barbara il pleuvait sans cesse sur...                            Barabara
# J'ai mis mon képi dans la cage  \net je suis so...                      Quartier libre
# Embauché malgré moi dans l’usine à idées  /n/j’...                                None
# notre pere qui etes aux cieux restez y et nous ...                        Pater noster
# il y en a qui s appellent aime bienvenu ou desi...          Il y en a qui s’appellent…
# j ai mis mon kepi dans la cage et je suis sorti...                      Quartier libre
# vous je ne vous regarde pas ma vie non plus ne ...                    Droits de regard
# trois allumettes une a une allumees dans la nui...                      Paris at night
#
#                                                     nb_like  haiku  \
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...      150  False
# deux et deux quatre quatre et quatre huit huit ...      150  False
# peindre d abord une cage avec une porte ouverte...       50  False
# rappelle toi barbara il pleuvait sans cesse sur...        0  False
# J'ai mis mon képi dans la cage  \net je suis so...        0  False
# Embauché malgré moi dans l’usine à idées  /n/j’...        0  False
# notre pere qui etes aux cieux restez y et nous ...        0  False
# il y en a qui s appellent aime bienvenu ou desi...        0  False
# j ai mis mon kepi dans la cage et je suis sorti...        0  False
# vous je ne vous regarde pas ma vie non plus ne ...        0  False
# trois allumettes une a une allumees dans la nui...        0  False
#
#                                                    quote_react  note
# text_tok
# il a mis le cafe dans la tasse il a mis le lait...         🎶🔥🌈  None
# deux et deux quatre quatre et quatre huit huit ...         🦎🌈🦋  None
# peindre d abord une cage avec une porte ouverte...           🦋  None
# rappelle toi barbara il pleuvait sans cesse sur...        None  None
# J'ai mis mon képi dans la cage  \net je suis so...        None  None
# Embauché malgré moi dans l’usine à idées  /n/j’...        None  None
# notre pere qui etes aux cieux restez y et nous ...        None  None
# il y en a qui s appellent aime bienvenu ou desi...        None  None
# j ai mis mon kepi dans la cage et je suis sorti...        None  None
# vous je ne vous regarde pas ma vie non plus ne ...        None  None
# trois allumettes une a une allumees dans la nui...        None  None

# %%
with open('bq_view_updated.sql', 'r') as f:
    query_view = f.read()
df_updated = pd.read_gbq(query_view, credentials=credentials)
df_updated.head()
# Out:
#                          timestamp                updated_timestamp  \
# 0 2024-11-19 22:10:51.069501+00:00 2024-11-19 22:10:51.069501+00:00
# 1 2024-11-19 23:52:05.722450+00:00 2024-11-19 23:52:05.722450+00:00
# 2 2024-11-19 23:52:05.722450+00:00 2024-11-19 23:52:05.722450+00:00
# 3 2024-11-18 00:16:09.377227+00:00 2024-11-18 00:16:09.377227+00:00
# 4 2024-11-17 23:42:45.546705+00:00 2024-11-17 23:42:45.546705+00:00
#
#                                                quote  \
# 0  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 1  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 2  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 3  {'title': 'None', 'author': 'tiktok', 'text': ...
# 4  {'title': 'None', 'author': 'Thomas', 'text': ...
#
#                                 extra  \
# 0  {'quote_react': '𝄞', 'note': None}
# 1  {'quote_react': '𝄞', 'note': None}
# 2  {'quote_react': '𝄞', 'note': None}
# 3  {'quote_react': '𝄞', 'note': None}
# 4  {'quote_react': '𝄞', 'note': None}
#
#                                                 info  is_delete
# 0  {'text_tok': 'Scoobydoobydoo-music !!!', 'nb_c...      False
# 1  {'text_tok': 'Scoobydoobydoo Fire !', 'nb_char...      False
# 2  {'text_tok': 'Scoobydoobydoo Fire !', 'nb_char...      False
# 3  {'text_tok': 'Un oiseau ne chante pas parce qu...      False
# 4  {'text_tok': 'La danse m'a appris davantage qu...      False

# %%
df_updated.iloc[2]
# Out:
# text                                Scoobydoobydoo Fire !
# author                                         Scooby-Doo
# book                                                 None
# title                                                None
# nb_like                                              2700
# haiku                                               False
# quote_react                                             𝄞
# note                                                 None
# all_search     scoobydoobydoo fire scooby doo none none 𝄞
# is_delete                                           False
# Name: Scoobydoobydoo Fire !, dtype: object

# %%
df_updated['info'].apply(lambda x: x['text_tok'])
df_updated.iloc[23:26]
# Out:
#                    timestamp                updated_timestamp  \
# 23 2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 24 2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 25 2024-11-17 00:00:00+00:00 2024-11-19 23:47:20.070699+00:00
#
#                                                 quote  \
# 23  {'title': None, 'author': 'Pierre Desproges', ...
# 24  {'title': None, 'author': 'Yasmina Khadra', 't...
# 25  {'title': None, 'author': 'Kerouac', 'text': '...
#
#                                                 extra  \
# 23                {'quote_react': None, 'note': None}
# 24                {'quote_react': None, 'note': None}
# 25  {'quote_react': '🌚🌚🌚🌚🌚🌚🎶', 'note': 'Useless ! ...
#
#                                                  info  is_delete
# 23  {'text_tok': 'les enfants c est comme les pets...       True
# 24  {'text_tok': 'celui qui passe a cote de la plu...       <NA>
# 25  {'text_tok': 'inutile inutile la pluie lourde ...       <NA>

# %%
df_updated['text'] = df_updated['quote'].apply(lambda x: x.get('text', ''))
df_updated['text_tok'] = df_updated['quote'].apply(lambda x: tokenize(x.get('text', '')))
df_updated['author'] = df_updated['quote'].apply(lambda x: x.get('author', ''))
df_updated['book'] = df_updated['quote'].apply(lambda x: x.get('book', ''))
df_updated['title'] = df_updated['quote'].apply(lambda x: x.get('title', ''))
df_updated['quote_react'] = df_updated['extra'].apply(lambda x: x.get('quote_react', ''))
df_updated['note'] = df_updated['extra'].apply(lambda x: x.get('note', ''))
df_updated['haiku'] = df_updated['text'].apply(lambda x: len(x.split('\n')) == 3)
df_updated['nb_like'] = 0
df_updated['all_search'] = (df_updated['text_tok'].astype(str)) + (df_updated['author'].astype(str).apply(tokenize)) + (df_updated['book'].astype(str).apply(tokenize)) + (df_updated['title'].astype(str).apply(tokenize)) + df_updated['quote_react'].astype(str)

df_updated = df_updated[['text', 'author', 'book', 'title', 'nb_like', 'text_tok', 'haiku', 'quote_react', 'note', 'all_search', 'is_delete']]
# df_updated.set_index('text_tok', inplace = True, drop = True)
df_updated.iloc[23:26]
# Out:
#                                                  text            author  \
# 23  Les enfants, c'est comme les pets. Il n'y a qu...  Pierre Desproges
# 24  Celui qui passe à côté de la plus belle histoi...    Yasmina Khadra
# 25  Inutile ! inutile !  \n– la pluie lourde s’enf...           Kerouac
#
#                              book title  nb_like  \
# 23                           None  None        0
# 24  Ce que le jour doit à la nuit  None        0
# 25               Livre des haïkus  None        0
#
#                                              text_tok  haiku quote_react  \
# 23  les enfants c est comme les pets il n y a que ...  False        None
# 24  celui qui passe a cote de la plus belle histoi...  False        None
# 25  inutile inutile la pluie lourde s enfonce dans...   True     🌚🌚🌚🌚🌚🌚🎶
#
#                                                  note  \
# 23                                               None
# 24                                               None
# 25  Useless ! Useless !  \n— heavy rain driving  \...
#
#                                            all_search  is_delete
# 23  les enfants c est comme les pets il n y a que ...       True
# 24  celui qui passe a cote de la plus belle histoi...       <NA>
# 25  inutile inutile la pluie lourde s enfonce dans...       <NA>

# %%
df_updated = df_updated[['text', 'author', 'book', 'title', 'nb_like', 'text_tok', 'haiku', 'quote_react', 'note', 'all_search', 'is_delete']]
df_updated.set_index('text_tok', inplace = True, drop = True)
df_updated.iloc[23:26]
# Out:
#                                                                                                  text  \
# text_tok
# les enfants c est comme les pets il n y a que l...  Les enfants, c'est comme les pets. Il n'y a qu...
# celui qui passe a cote de la plus belle histoir...  Celui qui passe à côté de la plus belle histoi...
# inutile inutile la pluie lourde s enfonce dans ...  Inutile ! inutile !  \n– la pluie lourde s’enf...
#
#                                                               author  \
# text_tok
# les enfants c est comme les pets il n y a que l...  Pierre Desproges
# celui qui passe a cote de la plus belle histoir...    Yasmina Khadra
# inutile inutile la pluie lourde s enfonce dans ...           Kerouac
#
#                                                                              book  \
# text_tok
# les enfants c est comme les pets il n y a que l...                           None
# celui qui passe a cote de la plus belle histoir...  Ce que le jour doit à la nuit
# inutile inutile la pluie lourde s enfonce dans ...               Livre des haïkus
#
#                                                    title  nb_like  haiku  \
# text_tok
# les enfants c est comme les pets il n y a que l...  None        0  False
# celui qui passe a cote de la plus belle histoir...  None        0  False
# inutile inutile la pluie lourde s enfonce dans ...  None        0   True
#
#                                                    quote_react  \
# text_tok
# les enfants c est comme les pets il n y a que l...        None
# celui qui passe a cote de la plus belle histoir...        None
# inutile inutile la pluie lourde s enfonce dans ...     🌚🌚🌚🌚🌚🌚🎶
#
#                                                                                                  note  \
# text_tok
# les enfants c est comme les pets il n y a que l...                                               None
# celui qui passe a cote de la plus belle histoir...                                               None
# inutile inutile la pluie lourde s enfonce dans ...  Useless ! Useless !  \n— heavy rain driving  \...
#
#                                                                                            all_search  \
# text_tok
# les enfants c est comme les pets il n y a que l...  les enfants c est comme les pets il n y a que ...
# celui qui passe a cote de la plus belle histoir...  celui qui passe a cote de la plus belle histoi...
# inutile inutile la pluie lourde s enfonce dans ...  inutile inutile la pluie lourde s enfonce dans...
#
#                                                     is_delete
# text_tok
# les enfants c est comme les pets il n y a que l...       True
# celui qui passe a cote de la plus belle histoir...       <NA>
# inutile inutile la pluie lourde s enfonce dans ...       <NA>

# %%
df_updated[df_updated['author'] == 'Scooby-Doo']
# Out:
#                                               text      author  book  \
# text_tok
# Scoobydoobydoo-music !!!  Scoobydoobydoo-music !!!  Scooby-Doo  None
# Scoobydoobydoo Fire !        Scoobydoobydoo Fire !  Scooby-Doo  None
# Scoobydoobydoo Fire !        Scoobydoobydoo Fire !  Scooby-Doo  None
# Scoobydoobydoo !                  Scoobydoobydoo !  Scooby-Doo  None
# Scoobydoobydoo !                  Scoobydoobydoo !  Scooby-Doo  None
# Scoobydoobydoo !                  Scoobydoobydoo !  Scooby-Doo  None
# Scoobydoobydoo !                  Scoobydoobydoo !  Scooby-Doo  None
# Scoobydoobydoo !                  Scoobydoobydoo !  Scooby-Doo  None
# Scooby-Doo                              Scooby-Doo  Scooby-Doo  None
#
#                                title  nb_like  haiku quote_react  note  \
# text_tok
# Scoobydoobydoo-music !!!        None     2700  False           𝄞  None
# Scoobydoobydoo Fire !           None     2700  False           𝄞  None
# Scoobydoobydoo Fire !           None     2700  False           𝄞  None
# Scoobydoobydoo !                None     2700  False           𝄞  None
# Scoobydoobydoo !                None     2700  False           𝄞  None
# Scoobydoobydoo !                None     2700  False           𝄞  None
# Scoobydoobydoo !                None     2700  False           𝄞  None
# Scoobydoobydoo !                None     2700  False           𝄞  None
# Scooby-Doo                Scooby-Doo     2700  False           𝄞  None
#
#                                                            all_search  \
# text_tok
# Scoobydoobydoo-music !!!  scoobydoobydoo music scooby doo none none 𝄞
# Scoobydoobydoo Fire !      scoobydoobydoo fire scooby doo none none 𝄞
# Scoobydoobydoo Fire !      scoobydoobydoo fire scooby doo none none 𝄞
# Scoobydoobydoo !                scoobydoobydoo scooby doo none none 𝄞
# Scoobydoobydoo !                scoobydoobydoo scooby doo none none 𝄞
# Scoobydoobydoo !                scoobydoobydoo scooby doo none none 𝄞
# Scoobydoobydoo !                scoobydoobydoo scooby doo none none 𝄞
# Scoobydoobydoo !                scoobydoobydoo scooby doo none none 𝄞
# Scooby-Doo                    scooby doo scooby doo none scooby doo 𝄞
#
#                           is_delete
# text_tok
# Scoobydoobydoo-music !!!      False
# Scoobydoobydoo Fire !         False
# Scoobydoobydoo Fire !         False
# Scoobydoobydoo !              False
# Scoobydoobydoo !              False
# Scoobydoobydoo !              False
# Scoobydoobydoo !              False
# Scoobydoobydoo !              False
# Scooby-Doo                    False

# %%
df_updated.shape
# Out:
# (54, 10)

# %%
# data_ram = pd.read_parquet('data_v2/data_ram.parquet')
# data_ram[data_ram['author'] == "Scooby-Doo"]
data_v1 = pd.read_parquet('data_v2/raw_data_v1_17_nov_.parquet')

# %%
data_v1['note'] = data_v1['vo']
data_v1['all_search'] = (data_v1['text_tok'].astype(str)) + (data_v1['author'].astype(str).apply(tokenize)) + (data_v1['book'].astype(str).apply(tokenize)) + (data_v1['title'].astype(str).apply(tokenize)) + data_v1['quote_react'].astype(str)
data_v1.set_index('text_tok', inplace = True, drop = True)
data_v1.drop(['year', 'source', 'confiance', 'page', 'url', 'nb_char', 'nb_lines', 'sonnet', 'vo'], axis = 1, inplace = True)
data_v1['is_delete'] = False
print('data_v1 loaded')

# add events
with open('bq_view_updated.sql', 'r') as f:
    query_view = f.read()
df_updated = pd.read_gbq(query_view, credentials=credentials)
print(f'{len(df_updated)} events loaded')

df_updated['text'] = df_updated['quote'].apply(lambda x: x.get('text', ''))
df_updated['text_tok'] = df_updated['quote'].apply(lambda x: x.get('text', '')) # no tokenize (events text_tok are consider as is (will be tokenize in all_search))
df_updated['author'] = df_updated['quote'].apply(lambda x: x.get('author', ''))
df_updated['book'] = df_updated['quote'].apply(lambda x: x.get('book', ''))
df_updated['title'] = df_updated['quote'].apply(lambda x: x.get('title', ''))
df_updated['quote_react'] = df_updated['extra'].apply(lambda x: x.get('quote_react', ''))
df_updated['note'] = df_updated['extra'].apply(lambda x: x.get('note', ''))
df_updated['haiku'] = df_updated['text'].apply(lambda x: len(x.split('\n')) == 3)
df_updated['nb_like'] = len(df_updated['quote_react']) * 50
df_updated['all_search'] = (df_updated['text_tok'].astype(str).apply(tokenize)) + ' ' + (df_updated['author'].astype(str).apply(tokenize)) +' ' + (df_updated['book'].astype(str).apply(tokenize)) + ' ' +(df_updated['title'].astype(str).apply(tokenize)) +' ' + df_updated['quote_react'].astype(str)

df_updated = df_updated[['text', 'author', 'book', 'title', 'nb_like', 'text_tok', 'haiku', 'quote_react', 'note', 'all_search', 'is_delete']]
df_updated.set_index('text_tok', inplace = True, drop = True)

data_ram = pd.concat([df_updated, data_v1], axis = 0)
data_ram['is_delete'] = data_ram['is_delete'].replace(np.nan, False)
# drop duplicates index
data_ram = data_ram[~data_ram.index.duplicated(keep='first')]
data_ram.sort_values('nb_like', ascending = False, inplace = True)
data_ram = data_ram[~data_ram['is_delete']]
data_ram.drop(['is_delete', 'all_search'], axis = 1, inplace = True)
# data_ram.drop(['is_delete'], axis = 1, inplace = True)

data_ram['author'] = data_ram['author'].astype(str)
data_ram['book'] = data_ram['book'].astype(str).replace('None', None)
data_ram['title'] = data_ram['title'].astype(str).replace('nan', None)
data_ram['quote_react'] = data_ram['quote_react'].astype(str).replace('None', None)
data_ram['note'] = data_ram['note'].astype(str).replace('nan', None)
# data_ram['all_search'] = data_ram['all_search'].astype(str)
data_ram['text'] = data_ram['text'].astype(str)
data_ram['haiku'] = data_ram['haiku'].astype(bool)
data_ram['nb_like'] = data_ram['nb_like'].astype(int)
# Out:
# data_v1 loaded
# 54 events loaded

# %%
data_ram[data_ram['author'] == 'Scooby-Doo']
# Out:
#                                               text      author  book  \
# text_tok
# Scoobydoobydoo-music !!!  Scoobydoobydoo-music !!!  Scooby-Doo  None
# Scoobydoobydoo Fire !        Scoobydoobydoo Fire !  Scooby-Doo  None
# Scoobydoobydoo !                  Scoobydoobydoo !  Scooby-Doo  None
# Scooby-Doo                              Scooby-Doo  Scooby-Doo  None
#
#                                title  nb_like  haiku quote_react  note
# text_tok
# Scoobydoobydoo-music !!!        None     2700  False           𝄞  None
# Scoobydoobydoo Fire !           None     2700  False           𝄞  None
# Scoobydoobydoo !                None     2700  False           𝄞  None
# Scooby-Doo                Scooby-Doo     2700  False           𝄞  None

# %%
def get_kerouac(data_ram):
    z = data_ram[data_ram['author'] == "Kerouac"]
    pattern = "la pluie lourde"
    return z[z['text'].apply(lambda x: pattern in x).values]

get_kerouac(data_ram)
# Out:
#                                                                                                  text  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  Inutile ! inutile !  \n– la pluie lourde s’enf...
#   \nInutile ! Inutile !    \n– la pluie lourde ...    \nInutile ! Inutile !    \n– la pluie lourde...
# inutile inutile la pluie lourde s enfonce dans ...  Inutile ! inutile !  \n– la pluie lourde s’enf...
# inutile inutile la pluie lourde s enfonce s enf...    \nInutile ! Inutile !    \n– la pluie lourde...
# inutile inutile la pluie lourde s enfonce s enf...    \nInutile ! Inutile !    \n– la pluie lourde...
#
#                                                      author              book  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  Kerouac  Livre des haïkus
#   \nInutile ! Inutile !    \n– la pluie lourde ...  Kerouac  Livre des haïkus
# inutile inutile la pluie lourde s enfonce dans ...  Kerouac  Livre des haïkus
# inutile inutile la pluie lourde s enfonce s enf...  Kerouac  Livre des haïkus
# inutile inutile la pluie lourde s enfonce s enf...  Kerouac  Livre des haïkus
#
#                                                    title  nb_like  haiku  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  None     2600   True
#   \nInutile ! Inutile !    \n– la pluie lourde ...  None     2600  False
# inutile inutile la pluie lourde s enfonce dans ...  None      150   True
# inutile inutile la pluie lourde s enfonce s enf...  None       50  False
# inutile inutile la pluie lourde s enfonce s enf...  None       50  False
#
#                                                    quote_react  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...       🌚🌚🌚🌚🎶
#   \nInutile ! Inutile !    \n– la pluie lourde ...          🌚🎶
# inutile inutile la pluie lourde s enfonce dans ...           🎶
# inutile inutile la pluie lourde s enfonce s enf...           🎶
# inutile inutile la pluie lourde s enfonce s enf...        None
#
#                                                                                                  note
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  Useless ! Useless !  \n— heavy rain driving  \...
#   \nInutile ! Inutile !    \n– la pluie lourde ...  Useless ! Useless !  \n— heavy rain driving  \...
# inutile inutile la pluie lourde s enfonce dans ...  Useless ! Useless !  \n— heavy rain driving  \...
# inutile inutile la pluie lourde s enfonce s enf...  Useless ! Useless !  \n— heavy rain driving  \...
# inutile inutile la pluie lourde s enfonce s enf...  Useless ! Useless !  \n— heavy rain driving  \...

# %%
data_ram.shape
# Out:
# (56297, 8)

# %%
def load_data():
    data_ram = pd.read_parquet('data_v2/data_ram.parquet')
    # data_ram.set_index('text_tok', inplace = True, drop = True)
    data_ram['all_search'] = (data_ram.index.astype(str)) + (data_ram['author'].astype(str).apply(tokenize))+ (data_ram['text'].astype(str).apply(tokenize)) + (data_ram['book'].astype(str).apply(tokenize)) + (data_ram['title'].astype(str).apply(tokenize)) + data_ram['quote_react'].astype(str)
    data_ram.sort_values('nb_like', ascending = False, inplace = True)
    return data_ram
dr = load_data()
get_kerouac(dr)
# Out:
#                                                                                                  text  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  Inutile ! inutile !  \n– la pluie lourde s’enf...
# inutile inutile la pluie lourde s enfonce dans ...  Inutile ! inutile !  \n– la pluie lourde s’enf...
#
#                                                      author              book  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  Kerouac  Livre des haïkus
# inutile inutile la pluie lourde s enfonce dans ...  Kerouac  Livre des haïkus
#
#                                                    title  nb_like  haiku  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  None     2600   True
# inutile inutile la pluie lourde s enfonce dans ...  None      150   True
#
#                                                    quote_react  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...       🌚🌚🌚🌚🎶
# inutile inutile la pluie lourde s enfonce dans ...           🎶
#
#                                                                                                  note  \
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  Useless ! Useless !  \n— heavy rain driving  \...
# inutile inutile la pluie lourde s enfonce dans ...  Useless ! Useless !  \n— heavy rain driving  \...
#
#                                                                                            all_search
# text_tok
# Inutile ! inutile !  \n– la pluie lourde s’enfo...  Inutile ! inutile !  \n– la pluie lourde s’enf...
# inutile inutile la pluie lourde s enfonce dans ...  inutile inutile la pluie lourde s enfonce dans...

# %%
# create events_encoded
with open('bq_view_updated.sql', 'r') as f:
    query_view = f.read()
events = pd.read_gbq(query_view, credentials=credentials)
events['text_tok'] = events['info'].apply(lambda x: x['text_tok']).apply(tokenize)
events
# (CURRENT_timestamp(), "Inutile ! inutile !  \n– la pluie lourde s’enfonce  \nDans la mer", "localhost", "delete", "None", "None", "None", "None", "None") ,
#
# Out:
#                           timestamp                updated_timestamp  \
# 0  2024-11-18 00:16:09.377227+00:00 2024-11-18 00:16:09.377227+00:00
# 1  2024-11-17 23:42:45.546705+00:00 2024-11-17 23:42:45.546705+00:00
# 2  2024-11-17 23:41:36.402954+00:00 2024-11-17 23:41:36.402954+00:00
# 3  2024-11-17 23:42:45.546705+00:00 2024-11-17 23:42:45.546705+00:00
# 4  2024-11-17 23:42:45.546705+00:00 2024-11-17 23:42:45.546705+00:00
# 5  2024-11-17 23:41:36.402954+00:00 2024-11-17 23:41:36.402954+00:00
# 6  2024-11-17 23:41:36.402954+00:00 2024-11-17 23:41:36.402954+00:00
# 7  2024-11-18 00:12:44.219139+00:00 2024-11-18 00:12:44.219139+00:00
# 8  2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 9  2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 10 2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 11 2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 12 2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 13 2024-11-18 21:27:06.023360+00:00 2024-11-18 21:27:06.023360+00:00
# 14        2021-11-17 00:00:00+00:00        2021-11-17 00:00:00+00:00
# 15 2024-11-19 22:10:51.069501+00:00 2024-11-19 22:10:51.069501+00:00
# 16        2024-11-17 00:00:00+00:00 2024-11-18 21:27:24.863296+00:00
# 17        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 18        2024-11-17 00:00:00+00:00 2024-11-18 23:47:35.367103+00:00
# 19        2024-11-17 00:00:00+00:00 2024-11-18 01:08:14.232185+00:00
# 20        2024-11-17 00:00:00+00:00 2024-11-18 00:42:51.689737+00:00
# 21        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 22        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 23        2024-11-17 00:00:00+00:00 2024-11-19 22:43:48.797009+00:00
# 24        2024-11-17 00:00:00+00:00 2024-11-18 23:47:35.367103+00:00
# 25        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 26        2024-11-17 00:00:00+00:00 2024-11-18 22:03:22.258191+00:00
# 27        2024-11-17 00:00:00+00:00 2024-11-18 01:25:24.776500+00:00
# 28        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 29        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 30        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 31        2024-11-17 00:00:00+00:00 2024-11-17 23:42:45.546705+00:00
# 32        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 33        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 34        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 35        2024-11-17 00:00:00+00:00 2024-11-19 00:06:45.473178+00:00
# 36        2024-11-17 00:00:00+00:00 2024-11-17 23:42:45.546705+00:00
# 37        2024-11-17 00:00:00+00:00 2024-11-17 21:36:22.226027+00:00
# 38        2024-11-17 00:00:00+00:00 2024-11-17 22:25:30.114362+00:00
# 39        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 40        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 41        2024-11-17 00:00:00+00:00 2024-11-18 01:33:49.010681+00:00
# 42        2024-11-17 00:00:00+00:00 2024-11-17 21:38:39.268770+00:00
# 43        2024-11-17 00:00:00+00:00 2024-11-18 01:33:37.771225+00:00
# 44        2024-11-17 00:00:00+00:00 2024-11-17 21:48:36.208901+00:00
# 45        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 46        2024-11-17 00:00:00+00:00 2024-11-17 22:25:30.114362+00:00
# 47        2024-11-17 00:00:00+00:00 2024-11-17 21:37:45.845413+00:00
# 48        2024-11-17 00:00:00+00:00 2024-11-17 22:25:30.114362+00:00
# 49        2024-11-17 00:00:00+00:00 2024-11-17 22:32:43.691415+00:00
# 50        2024-11-17 00:00:00+00:00 2024-11-17 22:32:43.691415+00:00
# 51        2024-11-17 00:00:00+00:00 2024-11-17 22:32:43.691415+00:00
#
#                                                 quote  \
# 0   {'title': 'None', 'author': 'tiktok', 'text': ...
# 1   {'title': 'None', 'author': 'Thomas', 'text': ...
# 2   {'title': 'None', 'author': 'Thomas', 'text': ...
# 3   {'title': 'None', 'author': 'tiktok', 'text': ...
# 4   {'title': 'None', 'author': 'tiktok', 'text': ...
# 5   {'title': 'None', 'author': 'tiktok', 'text': ...
# 6   {'title': 'None', 'author': 'tiktok', 'text': ...
# 7   {'title': 'None', 'author': 'tiktok', 'text': ...
# 8   {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 9   {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 10  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 11  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 12  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 13  {'title': 'None', 'author': 'tiktok', 'text': ...
# 14  {'title': 'Scooby-Doo', 'author': 'Scooby-Doo'...
# 15  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 16  {'title': 'A', 'author': 'Blake', 'text': 'Les...
# 17  {'title': 'Pater noster', 'author': 'Prevert',...
# 18  {'title': None, 'author': 'Katô Gyôdai,', 'tex...
# 19  {'title': None, 'author': 'Oscar Wilde', 'text...
# 20  {'title': None, 'author': 'Antoine de Saint-Ex...
# 21  {'title': None, 'author': 'Pierre Desproges', ...
# 22  {'title': None, 'author': 'Yasmina Khadra', 't...
# 23  {'title': None, 'author': 'Kerouac', 'text': '...
# 24  {'title': None, 'author': 'Kerouac', 'text': '...
# 25  {'title': None, 'author': 'Kerouac', 'text': '...
# 26  {'title': None, 'author': ' Issa', 'text': 'Pr...
# 27  {'title': None, 'author': 'Jack Kerouac', 'tex...
# 28  {'title': None, 'author': 'Jack Kerouac', 'tex...
# 29  {'title': None, 'author': 'Bashô Matsuo', 'tex...
# 30  {'title': None, 'author': 'Bashô Matsuo', 'tex...
# 31  {'title': None, 'author': 'Bashô Matsuo', 'tex...
# 32  {'title': None, 'author': 'Paul Verlaine', 'te...
# 33  {'title': None, 'author': 'Paul Verlaine', 'te...
# 34  {'title': None, 'author': 'Paul Verlaine', 'te...
# 35  {'title': None, 'author': 'Natsume Soseki', 't...
# 36  {'title': None, 'author': 'Natsume Soseki', 't...
# 37  {'title': None, 'author': 'Christian Bobin', '...
# 38  {'title': None, 'author': 'Christian Bobin', '...
# 39  {'title': None, 'author': 'Christian Bobin', '...
# 40  {'title': None, 'author': 'Christian Bobin', '...
# 41  {'title': None, 'author': 'Christian Bobin', '...
# 42  {'title': None, 'author': 'Christian Bobin', '...
# 43  {'title': None, 'author': 'Christian Bobin', '...
# 44  {'title': None, 'author': 'Christian Bobin', '...
# 45  {'title': None, 'author': 'Christian Bobin', '...
# 46  {'title': None, 'author': 'Christian Bobin', '...
# 47  {'title': None, 'author': 'Christian Bobin', '...
# 48  {'title': None, 'author': 'Christian Bobin', '...
# 49  {'title': None, 'author': 'Éric-Emmanuel Schmi...
# 50  {'title': None, 'author': 'Éric-Emmanuel Schmi...
# 51  {'title': None, 'author': 'Éric-Emmanuel Schmi...
#
#                                                 extra  \
# 0                  {'quote_react': '𝄞', 'note': None}
# 1                  {'quote_react': '𝄞', 'note': None}
# 2                  {'quote_react': '𝄞', 'note': None}
# 3                  {'quote_react': '𝄞', 'note': None}
# 4                  {'quote_react': '𝄞', 'note': None}
# 5                  {'quote_react': '𝄞', 'note': None}
# 6                  {'quote_react': '𝄞', 'note': None}
# 7                  {'quote_react': '𝄞', 'note': None}
# 8                  {'quote_react': '𝄞', 'note': None}
# 9                  {'quote_react': '𝄞', 'note': None}
# 10                 {'quote_react': '𝄞', 'note': None}
# 11                 {'quote_react': '𝄞', 'note': None}
# 12                 {'quote_react': '𝄞', 'note': None}
# 13                 {'quote_react': '𝄞', 'note': None}
# 14                 {'quote_react': '𝄞', 'note': None}
# 15                 {'quote_react': '𝄞', 'note': None}
# 16                {'quote_react': '🌚🌈', 'note': None}
# 17                {'quote_react': None, 'note': None}
# 18                {'quote_react': '🌚🦋', 'note': None}
# 19                {'quote_react': None, 'note': None}
# 20                {'quote_react': None, 'note': None}
# 21                {'quote_react': None, 'note': None}
# 22                {'quote_react': None, 'note': None}
# 23  {'quote_react': '🌚🌚🌚🌚🎶', 'note': 'Useless ! Us...
# 24  {'quote_react': '🌚🎶', 'note': 'Useless ! Usele...
# 25  {'quote_react': None, 'note': 'Useless ! Usele...
# 26                {'quote_react': '🌚🦋', 'note': None}
# 27                {'quote_react': None, 'note': None}
# 28                {'quote_react': None, 'note': None}
# 29            {'quote_react': '🌚🌚⛩️🎶🦋', 'note': None}
# 30                {'quote_react': '🌚🦋', 'note': None}
# 31                {'quote_react': None, 'note': None}
# 32                {'quote_react': None, 'note': None}
# 33                {'quote_react': None, 'note': None}
# 34                {'quote_react': None, 'note': None}
# 35               {'quote_react': '🌚🦎🎶', 'note': None}
# 36                {'quote_react': None, 'note': None}
# 37                {'quote_react': '🦋🔥', 'note': None}
# 38                {'quote_react': None, 'note': None}
# 39               {'quote_react': '🔥🦎🍄', 'note': None}
# 40                {'quote_react': None, 'note': None}
# 41                {'quote_react': None, 'note': None}
# 42                {'quote_react': None, 'note': None}
# 43                {'quote_react': None, 'note': None}
# 44                {'quote_react': None, 'note': None}
# 45                {'quote_react': '🎶🍄', 'note': None}
# 46                {'quote_react': None, 'note': None}
# 47               {'quote_react': '🦋🌈🌈', 'note': None}
# 48                {'quote_react': None, 'note': None}
# 49                {'quote_react': None, 'note': None}
# 50                {'quote_react': None, 'note': None}
# 51                {'quote_react': None, 'note': None}
#
#                                                  info  is_delete  \
# 0   {'text_tok': 'Un oiseau ne chante pas parce qu...      False
# 1   {'text_tok': 'La danse m'a appris davantage qu...      False
# 2   {'text_tok': 'La danse m'a appris davantage qu...      False
# 3   {'text_tok': 'Un oiseau perché sur un arbre n'...      False
# 4   {'text_tok': 'Au départ, le peintre a une toil...      False
# 5   {'text_tok': 'Au départ, le peintre a une toil...      False
# 6   {'text_tok': 'Un oiseau perché sur un arbre n'...      False
# 7   {'text_tok': 'Un oiseau ne chante pas parce qu...      False
# 8   {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 9   {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 10  {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 11  {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 12  {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 13  {'text_tok': 'The real body count is how much ...      False
# 14  {'text_tok': 'Scooby-Doo', 'nb_char': None, 'n...      False
# 15  {'text_tok': 'Scoobydoobydoo-music !!!', 'nb_c...      False
# 16  {'text_tok': 'les sourires qu on a souris ne s...       <NA>
# 17  {'text_tok': 'notre pere qui etes aux cieux re...       True
# 18  {'text_tok': 'les feuilles tombent sur les feu...       <NA>
# 19  {'text_tok': 'soyez vous meme les autres sont ...       <NA>
# 20  {'text_tok': 'tu es responsable de ce que tu a...       <NA>
# 21  {'text_tok': 'les enfants c est comme les pets...       True
# 22  {'text_tok': 'celui qui passe a cote de la plu...       <NA>
# 23  {'text_tok': 'inutile inutile la pluie lourde ...       <NA>
# 24  {'text_tok': 'inutile inutile la pluie lourde ...       <NA>
# 25  {'text_tok': 'inutile inutile la pluie lourde ...       True
# 26  {'text_tok': 'prepare toi a la mort prepare to...       <NA>
# 27  {'text_tok': 'en ecoutant les oiseaux et leurs...       True
# 28  {'text_tok': 'la pluie lourde s enfonce dans l...       True
# 29  {'text_tok': 'neige qui tombait sur nous deux ...       <NA>
# 30  {'text_tok': 'tous deux nous la vimes cette an...       <NA>
# 31  {'text_tok': 'rien ne dit dans le chant de la ...       <NA>
# 32  {'text_tok': 'mon reve familier je fais souven...       True
# 33  {'text_tok': 'son regard est pareil au regard ...       True
# 34  {'text_tok': 'est elle brune blonde ou rousse ...       True
# 35  {'text_tok': 'les hommes meurent les hommes vi...       <NA>
# 36  {'text_tok': 'sur l aile du vent legere et loi...       <NA>
# 37  {'text_tok': 'nous n habitons pas des regions ...       <NA>
# 38  {'text_tok': 'la lecture est un billet d absen...       <NA>
# 39  {'text_tok': 'j ai le meme groupe sanguin que ...       <NA>
# 40  {'text_tok': 'on n a qu une faible idee de l a...       <NA>
# 41  {'text_tok': 'ce n est pas sa beaute sa force ...       <NA>
# 42  {'text_tok': 'lire pour se cultiver c est l ho...       <NA>
# 43  {'text_tok': 'rencontrer quelqu un le rencontr...       <NA>
# 44  {'text_tok': 'p 31 plus on s approche de la lu...       <NA>
# 45  {'text_tok': 'le sens de cette vie c est de vo...       <NA>
# 46  {'text_tok': 'les livres aimes se melent au pa...       True
# 47  {'text_tok': 'ce qui fait evenement c est ce q...       <NA>
# 48  {'text_tok': 'ils craignent la mort sans voir ...       <NA>
# 49  {'text_tok': 'le bonheur qu on attend gache pa...       <NA>
# 50  {'text_tok': 'le plus difficile dans une discu...       <NA>
# 51  {'text_tok': 'quel que soit l age auquel on ap...       <NA>
#
#                                              text_tok
# 0   un oiseau ne chante pas parce qu il a une repo...
# 1   la danse m a appris davantage que de deplacer ...
# 2   la danse m a appris davantage que de deplacer ...
# 3   un oiseau perche sur un arbre n a jamais peur ...
# 4   au depart le peintre a une toile l ecrivain a ...
# 5   au depart le peintre a une toile l ecrivain a ...
# 6   un oiseau perche sur un arbre n a jamais peur ...
# 7   un oiseau ne chante pas parce qu il a une repo...
# 8                                      scoobydoobydoo
# 9                                      scoobydoobydoo
# 10                                     scoobydoobydoo
# 11                                     scoobydoobydoo
# 12                                     scoobydoobydoo
# 13  the real body count is how much people are in ...
# 14                                         scooby doo
# 15                               scoobydoobydoo music
# 16  les sourires qu on a souris ne sont qu un uniq...
# 17  notre pere qui etes aux cieux restez y et nous...
# 18  les feuilles tombent sur les feuilles la pluie...
# 19          soyez vous meme les autres sont deja pris
# 20       tu es responsable de ce que tu as apprivoise
# 21  les enfants c est comme les pets il n y a que ...
# 22  celui qui passe a cote de la plus belle histoi...
# 23  inutile inutile la pluie lourde s enfonce dans...
# 24  inutile inutile la pluie lourde s enfonce s en...
# 25  inutile inutile la pluie lourde s enfonce s en...
# 26  prepare toi a la mort prepare toi bruissent le...
# 27  en ecoutant les oiseaux et leurs differentes v...
# 28  la pluie lourde s enfonce dans la mer inutile ...
# 29  neige qui tombait sur nous deux es tu la meme ...
# 30  tous deux nous la vimes cette annee est ce la ...
# 31  rien ne dit dans le chant de la cigale qu elle...
# 32  mon reve familier je fais souvent ce reve etra...
# 33  son regard est pareil au regard des statues et...
# 34  est elle brune blonde ou rousse je l ignore so...
# 35  les hommes meurent les hommes vivent passent l...
# 36  sur l aile du vent legere et lointaine l hiron...
# 37  nous n habitons pas des regions nous n habiton...
# 38  la lecture est un billet d absence une sortie ...
# 39  j ai le meme groupe sanguin que les abeilles l...
# 40  on n a qu une faible idee de l amour tant qu o...
# 41  ce n est pas sa beaute sa force et son esprit ...
# 42  lire pour se cultiver c est l horreur lire pou...
# 43  rencontrer quelqu un le rencontrer vraiment et...
# 44  p 31 plus on s approche de la lumiere plus on ...
# 45  le sens de cette vie c est de voir s effondrer...
# 46  les livres aimes se melent au pain que vous ma...
# 47  ce qui fait evenement c est ce qui est vivant ...
# 48  ils craignent la mort sans voir qu il y a une ...
# 49  le bonheur qu on attend gache parfois celui qu...
# 50  le plus difficile dans une discussion n est pa...
# 51  quel que soit l age auquel on apprend la mort ...

# %%
events
# Out:
#                           timestamp                updated_timestamp  \
# 0  2024-11-18 00:16:09.377227+00:00 2024-11-18 00:16:09.377227+00:00
# 1  2024-11-17 23:42:45.546705+00:00 2024-11-17 23:42:45.546705+00:00
# 2  2024-11-17 23:41:36.402954+00:00 2024-11-17 23:41:36.402954+00:00
# 3  2024-11-17 23:42:45.546705+00:00 2024-11-17 23:42:45.546705+00:00
# 4  2024-11-17 23:42:45.546705+00:00 2024-11-17 23:42:45.546705+00:00
# 5  2024-11-17 23:41:36.402954+00:00 2024-11-17 23:41:36.402954+00:00
# 6  2024-11-17 23:41:36.402954+00:00 2024-11-17 23:41:36.402954+00:00
# 7  2024-11-18 00:12:44.219139+00:00 2024-11-18 00:12:44.219139+00:00
# 8  2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 9  2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 10 2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 11 2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 12 2024-11-19 22:06:24.169798+00:00 2024-11-19 22:06:24.169798+00:00
# 13 2024-11-18 21:27:06.023360+00:00 2024-11-18 21:27:06.023360+00:00
# 14        2021-11-17 00:00:00+00:00        2021-11-17 00:00:00+00:00
# 15 2024-11-19 22:10:51.069501+00:00 2024-11-19 22:10:51.069501+00:00
# 16        2024-11-17 00:00:00+00:00 2024-11-18 21:27:24.863296+00:00
# 17        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 18        2024-11-17 00:00:00+00:00 2024-11-18 23:47:35.367103+00:00
# 19        2024-11-17 00:00:00+00:00 2024-11-18 01:08:14.232185+00:00
# 20        2024-11-17 00:00:00+00:00 2024-11-18 00:42:51.689737+00:00
# 21        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 22        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 23        2024-11-17 00:00:00+00:00 2024-11-19 22:43:48.797009+00:00
# 24        2024-11-17 00:00:00+00:00 2024-11-18 23:47:35.367103+00:00
# 25        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 26        2024-11-17 00:00:00+00:00 2024-11-18 22:03:22.258191+00:00
# 27        2024-11-17 00:00:00+00:00 2024-11-18 01:25:24.776500+00:00
# 28        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 29        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 30        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 31        2024-11-17 00:00:00+00:00 2024-11-17 23:42:45.546705+00:00
# 32        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 33        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 34        2024-11-17 00:00:00+00:00 2024-11-19 22:06:24.169798+00:00
# 35        2024-11-17 00:00:00+00:00 2024-11-19 00:06:45.473178+00:00
# 36        2024-11-17 00:00:00+00:00 2024-11-17 23:42:45.546705+00:00
# 37        2024-11-17 00:00:00+00:00 2024-11-17 21:36:22.226027+00:00
# 38        2024-11-17 00:00:00+00:00 2024-11-17 22:25:30.114362+00:00
# 39        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 40        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 41        2024-11-17 00:00:00+00:00 2024-11-18 01:33:49.010681+00:00
# 42        2024-11-17 00:00:00+00:00 2024-11-17 21:38:39.268770+00:00
# 43        2024-11-17 00:00:00+00:00 2024-11-18 01:33:37.771225+00:00
# 44        2024-11-17 00:00:00+00:00 2024-11-17 21:48:36.208901+00:00
# 45        2024-11-17 00:00:00+00:00 2024-11-18 23:45:42.184566+00:00
# 46        2024-11-17 00:00:00+00:00 2024-11-17 22:25:30.114362+00:00
# 47        2024-11-17 00:00:00+00:00 2024-11-17 21:37:45.845413+00:00
# 48        2024-11-17 00:00:00+00:00 2024-11-17 22:25:30.114362+00:00
# 49        2024-11-17 00:00:00+00:00 2024-11-17 22:32:43.691415+00:00
# 50        2024-11-17 00:00:00+00:00 2024-11-17 22:32:43.691415+00:00
# 51        2024-11-17 00:00:00+00:00 2024-11-17 22:32:43.691415+00:00
#
#                                                 quote  \
# 0   {'title': 'None', 'author': 'tiktok', 'text': ...
# 1   {'title': 'None', 'author': 'Thomas', 'text': ...
# 2   {'title': 'None', 'author': 'Thomas', 'text': ...
# 3   {'title': 'None', 'author': 'tiktok', 'text': ...
# 4   {'title': 'None', 'author': 'tiktok', 'text': ...
# 5   {'title': 'None', 'author': 'tiktok', 'text': ...
# 6   {'title': 'None', 'author': 'tiktok', 'text': ...
# 7   {'title': 'None', 'author': 'tiktok', 'text': ...
# 8   {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 9   {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 10  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 11  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 12  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 13  {'title': 'None', 'author': 'tiktok', 'text': ...
# 14  {'title': 'Scooby-Doo', 'author': 'Scooby-Doo'...
# 15  {'title': 'None', 'author': 'Scooby-Doo', 'tex...
# 16  {'title': 'A', 'author': 'Blake', 'text': 'Les...
# 17  {'title': 'Pater noster', 'author': 'Prevert',...
# 18  {'title': None, 'author': 'Katô Gyôdai,', 'tex...
# 19  {'title': None, 'author': 'Oscar Wilde', 'text...
# 20  {'title': None, 'author': 'Antoine de Saint-Ex...
# 21  {'title': None, 'author': 'Pierre Desproges', ...
# 22  {'title': None, 'author': 'Yasmina Khadra', 't...
# 23  {'title': None, 'author': 'Kerouac', 'text': '...
# 24  {'title': None, 'author': 'Kerouac', 'text': '...
# 25  {'title': None, 'author': 'Kerouac', 'text': '...
# 26  {'title': None, 'author': ' Issa', 'text': 'Pr...
# 27  {'title': None, 'author': 'Jack Kerouac', 'tex...
# 28  {'title': None, 'author': 'Jack Kerouac', 'tex...
# 29  {'title': None, 'author': 'Bashô Matsuo', 'tex...
# 30  {'title': None, 'author': 'Bashô Matsuo', 'tex...
# 31  {'title': None, 'author': 'Bashô Matsuo', 'tex...
# 32  {'title': None, 'author': 'Paul Verlaine', 'te...
# 33  {'title': None, 'author': 'Paul Verlaine', 'te...
# 34  {'title': None, 'author': 'Paul Verlaine', 'te...
# 35  {'title': None, 'author': 'Natsume Soseki', 't...
# 36  {'title': None, 'author': 'Natsume Soseki', 't...
# 37  {'title': None, 'author': 'Christian Bobin', '...
# 38  {'title': None, 'author': 'Christian Bobin', '...
# 39  {'title': None, 'author': 'Christian Bobin', '...
# 40  {'title': None, 'author': 'Christian Bobin', '...
# 41  {'title': None, 'author': 'Christian Bobin', '...
# 42  {'title': None, 'author': 'Christian Bobin', '...
# 43  {'title': None, 'author': 'Christian Bobin', '...
# 44  {'title': None, 'author': 'Christian Bobin', '...
# 45  {'title': None, 'author': 'Christian Bobin', '...
# 46  {'title': None, 'author': 'Christian Bobin', '...
# 47  {'title': None, 'author': 'Christian Bobin', '...
# 48  {'title': None, 'author': 'Christian Bobin', '...
# 49  {'title': None, 'author': 'Éric-Emmanuel Schmi...
# 50  {'title': None, 'author': 'Éric-Emmanuel Schmi...
# 51  {'title': None, 'author': 'Éric-Emmanuel Schmi...
#
#                                                 extra  \
# 0                  {'quote_react': '𝄞', 'note': None}
# 1                  {'quote_react': '𝄞', 'note': None}
# 2                  {'quote_react': '𝄞', 'note': None}
# 3                  {'quote_react': '𝄞', 'note': None}
# 4                  {'quote_react': '𝄞', 'note': None}
# 5                  {'quote_react': '𝄞', 'note': None}
# 6                  {'quote_react': '𝄞', 'note': None}
# 7                  {'quote_react': '𝄞', 'note': None}
# 8                  {'quote_react': '𝄞', 'note': None}
# 9                  {'quote_react': '𝄞', 'note': None}
# 10                 {'quote_react': '𝄞', 'note': None}
# 11                 {'quote_react': '𝄞', 'note': None}
# 12                 {'quote_react': '𝄞', 'note': None}
# 13                 {'quote_react': '𝄞', 'note': None}
# 14                 {'quote_react': '𝄞', 'note': None}
# 15                 {'quote_react': '𝄞', 'note': None}
# 16                {'quote_react': '🌚🌈', 'note': None}
# 17                {'quote_react': None, 'note': None}
# 18                {'quote_react': '🌚🦋', 'note': None}
# 19                {'quote_react': None, 'note': None}
# 20                {'quote_react': None, 'note': None}
# 21                {'quote_react': None, 'note': None}
# 22                {'quote_react': None, 'note': None}
# 23  {'quote_react': '🌚🌚🌚🌚🎶', 'note': 'Useless ! Us...
# 24  {'quote_react': '🌚🎶', 'note': 'Useless ! Usele...
# 25  {'quote_react': None, 'note': 'Useless ! Usele...
# 26                {'quote_react': '🌚🦋', 'note': None}
# 27                {'quote_react': None, 'note': None}
# 28                {'quote_react': None, 'note': None}
# 29            {'quote_react': '🌚🌚⛩️🎶🦋', 'note': None}
# 30                {'quote_react': '🌚🦋', 'note': None}
# 31                {'quote_react': None, 'note': None}
# 32                {'quote_react': None, 'note': None}
# 33                {'quote_react': None, 'note': None}
# 34                {'quote_react': None, 'note': None}
# 35               {'quote_react': '🌚🦎🎶', 'note': None}
# 36                {'quote_react': None, 'note': None}
# 37                {'quote_react': '🦋🔥', 'note': None}
# 38                {'quote_react': None, 'note': None}
# 39               {'quote_react': '🔥🦎🍄', 'note': None}
# 40                {'quote_react': None, 'note': None}
# 41                {'quote_react': None, 'note': None}
# 42                {'quote_react': None, 'note': None}
# 43                {'quote_react': None, 'note': None}
# 44                {'quote_react': None, 'note': None}
# 45                {'quote_react': '🎶🍄', 'note': None}
# 46                {'quote_react': None, 'note': None}
# 47               {'quote_react': '🦋🌈🌈', 'note': None}
# 48                {'quote_react': None, 'note': None}
# 49                {'quote_react': None, 'note': None}
# 50                {'quote_react': None, 'note': None}
# 51                {'quote_react': None, 'note': None}
#
#                                                  info  is_delete
# 0   {'text_tok': 'Un oiseau ne chante pas parce qu...      False
# 1   {'text_tok': 'La danse m'a appris davantage qu...      False
# 2   {'text_tok': 'La danse m'a appris davantage qu...      False
# 3   {'text_tok': 'Un oiseau perché sur un arbre n'...      False
# 4   {'text_tok': 'Au départ, le peintre a une toil...      False
# 5   {'text_tok': 'Au départ, le peintre a une toil...      False
# 6   {'text_tok': 'Un oiseau perché sur un arbre n'...      False
# 7   {'text_tok': 'Un oiseau ne chante pas parce qu...      False
# 8   {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 9   {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 10  {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 11  {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 12  {'text_tok': 'Scoobydoobydoo !', 'nb_char': No...      False
# 13  {'text_tok': 'The real body count is how much ...      False
# 14  {'text_tok': 'Scooby-Doo', 'nb_char': None, 'n...      False
# 15  {'text_tok': 'Scoobydoobydoo-music !!!', 'nb_c...      False
# 16  {'text_tok': 'les sourires qu on a souris ne s...       <NA>
# 17  {'text_tok': 'notre pere qui etes aux cieux re...       True
# 18  {'text_tok': 'les feuilles tombent sur les feu...       <NA>
# 19  {'text_tok': 'soyez vous meme les autres sont ...       <NA>
# 20  {'text_tok': 'tu es responsable de ce que tu a...       <NA>
# 21  {'text_tok': 'les enfants c est comme les pets...       True
# 22  {'text_tok': 'celui qui passe a cote de la plu...       <NA>
# 23  {'text_tok': 'inutile inutile la pluie lourde ...       <NA>
# 24  {'text_tok': 'inutile inutile la pluie lourde ...       <NA>
# 25  {'text_tok': 'inutile inutile la pluie lourde ...       True
# 26  {'text_tok': 'prepare toi a la mort prepare to...       <NA>
# 27  {'text_tok': 'en ecoutant les oiseaux et leurs...       True
# 28  {'text_tok': 'la pluie lourde s enfonce dans l...       True
# 29  {'text_tok': 'neige qui tombait sur nous deux ...       <NA>
# 30  {'text_tok': 'tous deux nous la vimes cette an...       <NA>
# 31  {'text_tok': 'rien ne dit dans le chant de la ...       <NA>
# 32  {'text_tok': 'mon reve familier je fais souven...       True
# 33  {'text_tok': 'son regard est pareil au regard ...       True
# 34  {'text_tok': 'est elle brune blonde ou rousse ...       True
# 35  {'text_tok': 'les hommes meurent les hommes vi...       <NA>
# 36  {'text_tok': 'sur l aile du vent legere et loi...       <NA>
# 37  {'text_tok': 'nous n habitons pas des regions ...       <NA>
# 38  {'text_tok': 'la lecture est un billet d absen...       <NA>
# 39  {'text_tok': 'j ai le meme groupe sanguin que ...       <NA>
# 40  {'text_tok': 'on n a qu une faible idee de l a...       <NA>
# 41  {'text_tok': 'ce n est pas sa beaute sa force ...       <NA>
# 42  {'text_tok': 'lire pour se cultiver c est l ho...       <NA>
# 43  {'text_tok': 'rencontrer quelqu un le rencontr...       <NA>
# 44  {'text_tok': 'p 31 plus on s approche de la lu...       <NA>
# 45  {'text_tok': 'le sens de cette vie c est de vo...       <NA>
# 46  {'text_tok': 'les livres aimes se melent au pa...       True
# 47  {'text_tok': 'ce qui fait evenement c est ce q...       <NA>
# 48  {'text_tok': 'ils craignent la mort sans voir ...       <NA>
# 49  {'text_tok': 'le bonheur qu on attend gache pa...       <NA>
# 50  {'text_tok': 'le plus difficile dans une discu...       <NA>
# 51  {'text_tok': 'quel que soit l age auquel on ap...       <NA>
